# %%
import pandas as pd

# %%
pd.read_csv("rfp_extraction_results.csv")
# Out:
#                                                source  \
# 0   /home/pyatrix/Downloads/rfp-sam-gov/output/BOD...
# 1   /home/pyatrix/Downloads/rfp-sam-gov/output/ASS...
# 2   /home/pyatrix/Downloads/rfp-sam-gov/output/Roo...
# 3   /home/pyatrix/Downloads/rfp-sam-gov/output/Roo...
# 4   /home/pyatrix/Downloads/rfp-sam-gov/output/Roo...
# 5   /home/pyatrix/Downloads/rfp-sam-gov/output/Roo...
# 6   /home/pyatrix/Downloads/rfp-sam-gov/output/Roo...
# 7   /home/pyatrix/Downloads/rfp-sam-gov/output/Bea...
# 8   /home/pyatrix/Downloads/rfp-sam-gov/output/Cou...
# 9   /home/pyatrix/Downloads/rfp-sam-gov/output/See...
# 10  /home/pyatrix/Downloads/rfp-sam-gov/output/441...
# 11  /home/pyatrix/Downloads/rfp-sam-gov/output/US ...
# 12  /home/pyatrix/Downloads/rfp-sam-gov/output/US ...
# 13  /home/pyatrix/Downloads/rfp-sam-gov/output/US ...
# 14  /home/pyatrix/Downloads/rfp-sam-gov/output/650...
# 15  /home/pyatrix/Downloads/rfp-sam-gov/output/Wil...
# ...
